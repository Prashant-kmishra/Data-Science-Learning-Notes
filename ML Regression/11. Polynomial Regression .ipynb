# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("polynomial_regression_car_price_dataset.csv")
df.head()
# Out:
#    km_driven  price_inr
# 0      63369    1455400
# 1     122026    1070100
# 2      78158    1309600
# 3     290929     432700
# 4      50580    1498300

# %%
fig, ax = plt.subplots()

ax.scatter(df["km_driven"],df["price_inr"])

# %%
X= df[["km_driven"]]
y= df["price_inr"]

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X,y,train_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_model = PolynomialFeatures(degree=2)

X_train_poly = poly_model.fit_transform(X_train)
X_test_poly = poly_model.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_poly)

mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

mse, r2
# Out:
# (2728506734.8028383, 0.9817172381984979)

# %% [markdown]
# NOTES
#
# ![image.png](attachment:1b5d48d3-5182-4060-8b4a-8bee13406558.png)
# ![image.png](attachment:8ccc5edc-2285-42bd-8af9-e5b4f4473f35.png)
# ![image.png](attachment:03cf5b7d-39b8-47ed-b21d-bff721d79f00.png)
# ![image.png](attachment:6667370a-f5d1-4df9-b6c6-78387438f04b.png)
# ![image.png](attachment:7a1fd49c-1bbe-480c-8608-b9fbc7af00a3.png)
# ![image.png](attachment:c7ad5854-077e-4f1b-ae5d-21f9057c5434.png)
