# %% [markdown]
# L1 regularisation = Lasso Regression
# L2 regularisation = Ridge Regression

# %%
import numpy as np 
import pandas as pd 
from sklearn.linear_model import LinearRegression , Lasso , Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("lasso_ridge_large_difference_dataset.csv")

# %%
df.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0 -0.608227  0.506241  0.049308 -0.471264  1.362563  0.355669  0.751099
# 1  0.695402  1.088770  0.140983 -0.080878  1.695723 -2.929449 -1.060605
# 2 -1.200296  1.266911  0.504987 -1.435862 -0.926930 -1.519370  0.010233
# 3 -1.893615 -0.264515 -0.792420 -0.973546  0.059933  0.829475  0.505470
# 4  0.586857 -0.783253  1.402794  0.346448  0.227460 -0.919424  0.232254
#
#          x8        x9       x10  ...       x42       x43       x44       x45  \
# 0  0.028458  1.923446 -1.123494  ...  0.532186 -0.461581  0.885083 -0.127918
# 1 -1.284584 -0.454548  1.023531  ...  1.092357  0.054367 -0.540226 -0.955540
# 2  0.462103 -0.440044 -1.024388  ...  1.320305 -0.905626 -1.228588 -1.606446
# 3  2.759660  0.209659 -1.308820  ... -0.297842 -1.722678  0.464789  0.203464
# 4 -0.714351  0.521942  0.184634  ... -0.787181  1.689228 -0.311475 -0.756351
#
#         x46       x47       x48       x49       x50      target
# ...

# %%
X= df.drop(columns=["target"])
y = df["target"]

# %%
X_train , X_test , y_train , y_test = train_test_split ( X, y , test_size=0.25 , random_state=42 )

# %%
lm = LinearRegression()

lm.fit(X_train,y_train)

lm.score(X_test,y_test)
# Out:
# 0.5429570706419513

# %%
lm.score(X_train,y_train)
# Out:
# 0.9019370754153241

# %%
lasso_model = Lasso(alpha=2.0)
lasso_model.fit(X_train,y_train)
lasso_model.score(X_test,y_test)
# Out:
# 0.6467132693871498

# %%
ridge_model = Ridge(alpha=9)
ridge_model.fit(X_train,y_train)
ridge_model.score(X_test,y_test)
# Out:
# 0.6214772415389935

# %% [markdown]
# ![image.png](attachment:06a19ba5-9f58-438a-87ea-eb129b1da8ca.png)
# ![image.png](attachment:3e7a96ac-c58c-4d40-9eb5-c3426e1317c6.png)

# %% [markdown]
# To check your training error, you run the exact same score() method or r2_score() function, but you pass your training variables (X_train, y_train) instead of your test variables.
#
# ![image.png](attachment:73347a97-c265-44e1-8ac3-bbfd3fe2b0be.png)
